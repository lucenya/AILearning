# %%
import wikipedia
#print wikipedia.summary("Wikipedia")
# Wikipedia (/ˌwɪkɨˈpiːdiə/ or /ˌwɪkiˈpiːdiə/ WIK-i-PEE-dee-ə) is a collaboratively edited, multilingual, free Internet encyclopedia supported by the non-profit Wikimedia Foundation...

wikipedia.search("Nike, Inc.")
content = wikipedia.page("Nike, Inc.")

# %%
print(content.categories)
# Out:
# ['1964 establishments in Oregon', '1970s fashion', '1980s fashion', '1990s fashion', '2000s fashion', '2010s fashion', 'All articles lacking reliable references', 'All articles with dead external links', 'All articles with failed verification', 'Articles lacking reliable references from April 2016', 'Articles with dead external links from July 2017', 'Articles with dead external links from September 2010', 'Articles with failed verification from August 2017', 'Articles with inconsistent citation formats', 'Athletic shoe brands', 'CS1 errors: missing author or editor', 'Clothing companies of the United States', 'Companies based in Beaverton, Oregon', 'Companies established in 1964', 'Companies in the Dow Jones Industrial Average', 'Companies listed on the New York Stock Exchange', 'Coordinates not on Wikidata', 'Multinational companies headquartered in the United States', 'Nike, Inc.', 'Nike brands', 'Pages using deprecated image syntax', 'Shoe companies of the United States', 'Sporti
# ...

# %%
print(content.content)
# Out:
# Nike, Inc. (official, US: ; also, non-US ) is an American multinational corporation that is engaged in the design, development, manufacturing, and worldwide marketing and sales of footwear, apparel, equipment, accessories, and services. The company is headquartered near Beaverton, Oregon, in the Portland metropolitan area. It is the world's largest supplier of athletic shoes and apparel and a major manufacturer of sports equipment, with revenue in excess of US$24.1 billion in its fiscal year 2012 (ending May 31, 2012). As of 2012, it employed more than 44,000 people worldwide. In 2014 the brand alone was valued at $19 billion, making it the most valuable brand among sports businesses. As of 2017, the Nike brand is valued at $29.6 billion.
# ...

# %%
print(content.coordinates)
# Out:
# (Decimal('45.50930000000000319460013997741043567657470703125'), Decimal('-122.8298999999999949750417727045714855194091796875'))

# %%
print(content.html())
# Out:
# <div class="mw-parser-output"><div role="note" class="hatnote navigation-not-searchable">This article is about the sportswear and apparel company. For other uses of the name "Nike", see <a href="/wiki/Nike_(disambiguation)" class="mw-redirect mw-disambig" title="Nike (disambiguation)">Nike (disambiguation)</a>.</div>
# <p>
#
# </p>
# <table class="infobox vcard" style="width:22em"><caption class="fn org">Nike, Inc.</caption><tr><td colspan="2" class="logo" style="text-align:center">
# ...

# %%
print(content.images)
# Out:
# ['https://upload.wikimedia.org/wikipedia/commons/a/aa/Airjordan1985-1st.JPG', 'https://upload.wikimedia.org/wikipedia/commons/b/b9/Flag_of_Oregon.svg', 'https://upload.wikimedia.org/wikipedia/commons/b/b0/Increase2.svg', 'https://upload.wikimedia.org/wikipedia/commons/2/2a/Industry5.svg', 'https://upload.wikimedia.org/wikipedia/commons/a/a6/Logo_NIKE.svg', 'https://upload.wikimedia.org/wikipedia/commons/0/02/NikeCanada.jpg', 'https://upload.wikimedia.org/wikipedia/commons/3/3a/NikeFactoryStoreVaughanMills.JPG', 'https://upload.wikimedia.org/wikipedia/commons/5/54/Nike_no-show_socks.JPG', 'https://upload.wikimedia.org/wikipedia/commons/d/dc/Niketown08.jpg', 'https://upload.wikimedia.org/wikipedia/commons/3/35/Nikeworldheadquarters.jpg', 'https://upload.wikimedia.org/wikipedia/commons/9/94/Old_Nike_logo.jpg', 'https://upload.wikimedia.org/wikipedia/commons/f/fc/Padlock-silver.svg', 'https://upload.wikimedia.org/wikipedia/commons/7/79/Ronaldinho_11feb2007.jpg', 'https://upload.wikimedia
# ...

# %%
print(content.links)
# Out:
# ['1960 Summer Olympics', '1990s fashion', '2000s youth fashion', '2010s in fashion', '3M', 'A-dec', 'ASICS', 'Adidas', 'Air Force 1 (shoe)', 'Air Jordan', 'Air Jordans', 'Air Max', 'Air Melo Line', 'Alcoa', 'Altra Running', 'American English', 'American Express', 'American football', 'Andrés Iniesta', 'Anti-globalisation', 'Anti-sweatshop', 'Apparel', 'Apple Inc.', 'Apple Records', 'Appleby (law firm)', 'Asset', 'Associated Press', 'Athletic shoe', 'BBC', 'Baseball cap', 'Baselayers', 'Basketball', 'Basketball uniform', 'Bauer Hockey', 'Beaverton, Oregon', 'Bermuda', 'Bi-Mart', 'Bill Bowerman', 'Board of directors', 'Bob Hurley', 'Boeing', 'Bomber jacket', 'Broadcast', 'Brooks Sports', 'Capitol Records', 'Carl Lewis', 'Carolyn Davidson', 'Casual chic', 'Caterpillar Inc.', 'Charlotte Hornets', 'Cheerleading', 'Chevron Corporation', 'Child labor', 'Child labour in Cambodia', 'Child labour in Pakistan', 'Chuck Taylor All-Stars', 'Cisco Systems', 'Cleat (shoe)', 'Climate Counts', 'Clothi
# ...

# %%
print(content.original_title)
# Out:
# Nike, Inc.

# %%
print(content.pageid)
# Out:
# 18998781

# %%
print(content.parent_id)
# Out:
# 811865248

# %%
print(content.references)
# Out:
# ['http://doi.org/10.1080%2F15459620701853342', 'http://doi.org/10.1093%2Fannhyg%2Fmen003', 'http://tools.wmflabs.org/geohack/geohack.php?pagename=Nike,_Inc.&params=45.5093_N_-122.8299_E_region:US_type:landmark', 'http://www.ncbi.nlm.nih.gov/pubmed/18213531', 'http://www.ncbi.nlm.nih.gov/pubmed/18344534', 'http://abcnews.go.com/Business/wireStory/nike-fiscal-2nd-quarter-profit-40-percent-21280853', 'http://blog.oregonlive.com/oregonianextra/2006/06/appellate_court_rejects_beaver.html', 'http://blogs.marketwatch.com/behindthestorefront/2014/05/02/style-conscious-men-prove-colorful-socks-no-longer-a-fad/', 'http://climatecounts.org/scorecompany.php?co=43', 'http://footwearnews.com/2016/focus/athletic-outdoor/nike-air-zoom-vomero-11-sneakers-release-199000/', 'http://hannahgale.co.uk/2015/01/22/26-signs-youre-the-absolute-queen-of-basic-bitches/', 'http://hudsonreporter.com/view/full_stories_home/2408547/article-Truant-officer-was-Olympic-hero-Emerson-High-has-gold-medallist-in-midst?', 
# ...

# %%
print(content.revision_id)
# Out:
# 813666023

# %%
print(content.section)
# Out:
# <bound method WikipediaPage.section of <WikipediaPage 'Nike, Inc.'>>

# %%
print(content.sections)
# Out:
# []

# %%
print(content.summary)
# Out:
# Nike, Inc. (official, US: ; also, non-US ) is an American multinational corporation that is engaged in the design, development, manufacturing, and worldwide marketing and sales of footwear, apparel, equipment, accessories, and services. The company is headquartered near Beaverton, Oregon, in the Portland metropolitan area. It is the world's largest supplier of athletic shoes and apparel and a major manufacturer of sports equipment, with revenue in excess of US$24.1 billion in its fiscal year 2012 (ending May 31, 2012). As of 2012, it employed more than 44,000 people worldwide. In 2014 the brand alone was valued at $19 billion, making it the most valuable brand among sports businesses. As of 2017, the Nike brand is valued at $29.6 billion.
# ...

# %%
print(content.title)
# Out:
# Nike, Inc.

# %%
print(content.url)
# Out:
# https://en.wikipedia.org/wiki/Nike,_Inc.

# %%
print(content.section)
# Out:
# <bound method WikipediaPage.section of <WikipediaPage 'Nike, Inc.'>>
